# %% [markdown]
# # Hotdog / Not Hotdog Classification - transfer learning
#
# https://drive.google.com/file/d/1FZ3ZwcPDoEave_xp50Ziue39gMhGPO1W/view

# %% [markdown]
# ## Imports

# %%
from math import ceil

import numpy as np

import tensorflow as tf

tf.logging.set_verbosity(tf.logging.ERROR)

from keras.applications import vgg16
from keras.applications.vgg16 import VGG16
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense
from keras.optimizers import SGD, RMSprop
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Using the bottleneck features of a pre-trained network

# %%
vgg_model = VGG16(include_top=False, weights="imagenet")
print(vgg_model.summary())
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
TRAIN_DATA_DIR = "data/train"
VALIDATION_DATA_DIR = "data/test"
BOTTLENECK_FEATURES_TRAIN_PATH = "auxiliary/bottleneck_features_train.npy"
BOTTLENECK_FEATURES_VALIDATION_PATH = "auxiliary/bottleneck_features_validation.npy"
TOP_MODEL_WEIGHTS_PATH = "auxiliary/bottleneck_fc_model.h5"
TUNED_VGG_WEIGHTS_PATH = "auxiliary/tuned_vgg_model.h5"

TRAIN_CLASS_SIZE = 249
VALIDATION_CLASS_SIZE = 250

IMG_WIDTH, IMG_HEIGHT = 150, 150
BATCH_SIZE = 16

# %%
def get_data_generator():
    datagen = ImageDataGenerator(preprocessing_function=vgg16.preprocess_input)
    return datagen


def get_batches(
    path,
    datagen=get_data_generator(),
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    shuffle=True,
    save_to_dir=None,
):
    generator = datagen.flow_from_directory(
        path,
        target_size=target_size,
        batch_size=batch_size,
        class_mode=class_mode,
        shuffle=shuffle,
        save_to_dir=save_to_dir,
    )
    return generator

# %% [markdown]
# We will run our loaded VGG16 model on our training and validation data once, recording the output (the "bottleneck features" from the VGG16 model: the last activation maps before the fully-connected layers) in two numpy arrays. Then we will train a small fully-connected model on top of the stored features.
#
# Below `class_mode=None` means our generator will only yield batches of data without labels, and `shuffle=False` means our data will be in order, so first images will be hotdogs, then not hotdogs. We have exact same number of objects in classes both on train and validation, so here we set `batch_size` to class size and fit generator data in two steps. We do this to use all our training and validation samples by having sample size be multiple of class size, which we wouldn't be able to do if we were using some conventional batch size of 16 or 32 here.

# %%
train_generator = get_batches(
    TRAIN_DATA_DIR,
    batch_size=TRAIN_CLASS_SIZE,
    class_mode=None,
    shuffle=False,
    save_to_dir="auxiliary/preview_train",
)
bottleneck_features_train = vgg_model.predict_generator(train_generator, steps=2)
np.save(open(BOTTLENECK_FEATURES_TRAIN_PATH, "wb"), bottleneck_features_train)

validation_generator = get_batches(
    VALIDATION_DATA_DIR,
    batch_size=VALIDATION_CLASS_SIZE,
    class_mode=None,
    shuffle=False,
    save_to_dir="auxiliary/preview_validation",
)
bottleneck_features_validation = vgg_model.predict_generator(validation_generator, steps=2)
np.save(open(BOTTLENECK_FEATURES_VALIDATION_PATH, "wb"), bottleneck_features_validation)
# Out:
# Found 498 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %% [markdown]
# We'll create a function for generation of our top fully-connected model since we'll be reusing it later.

# %%
def generate_top_model(input_shape):
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation="sigmoid"))
    return model

# %%
train_data = np.load(open(BOTTLENECK_FEATURES_TRAIN_PATH, "rb"))
# the features were saved in order, so recreating the labels is easy
train_labels = np.array([0] * TRAIN_CLASS_SIZE + [1] * TRAIN_CLASS_SIZE)

validation_data = np.load(open(BOTTLENECK_FEATURES_VALIDATION_PATH, "rb"))
validation_labels = np.array([0] * VALIDATION_CLASS_SIZE + [1] * VALIDATION_CLASS_SIZE)

model = generate_top_model(input_shape=train_data.shape[1:])
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

# %%
# es = EarlyStopping(monitor="val_loss", mode="min", patience=5, verbose=1)

# reduce_lr = ReduceLROnPlateau(
#     monitor="val_acc", patience=5, verbose=1, factor=0.5, min_lr=1e-4
# )

checkpoint = ModelCheckpoint(
    TOP_MODEL_WEIGHTS_PATH,
    monitor="val_acc",
    verbose=1,
    save_best_only=True,
    mode="max",
)

model.fit(
    train_data,
    train_labels,
    epochs=200,
    batch_size=BATCH_SIZE,
    validation_data=(validation_data, validation_labels),
    callbacks=[checkpoint],
)
# Out:
# Train on 498 samples, validate on 500 samples
# Epoch 1/200
# 498/498 [==============================] - 1s 3ms/step - loss: 6.0551 - acc: 0.6024 - val_loss: 5.8707 - val_acc: 0.6160
#
# Epoch 00001: val_acc improved from -inf to 0.61600, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 2/200
# 498/498 [==============================] - 1s 2ms/step - loss: 4.1459 - acc: 0.7289 - val_loss: 4.3839 - val_acc: 0.7120
#
# Epoch 00002: val_acc improved from 0.61600 to 0.71200, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 3/200
# 498/498 [==============================] - 1s 2ms/step - loss: 3.8449 - acc: 0.7430 - val_loss: 3.3066 - val_acc: 0.7740
#
# Epoch 00003: val_acc improved from 0.71200 to 0.77400, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 4/200
# 498/498 [==============================] - 1s 2ms/step - loss: 3.5470 - acc: 0.7711 - val_loss: 2.9035 - val_acc: 0.8040
#
# Epoch 00004: val_acc improved from 0.77400 to 0.80400, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 5/200
# 498/498 [==============================] - 1s 2ms/step - loss: 3.5120 - acc: 0.7731 - val_loss: 3.6605 - val_acc: 0.7600
#
# Epoch 00005: val_acc did not improve from 0.80400
# Epoch 6/200
# 498/498 [==============================] - 1s 2ms/step - loss: 3.2669 - acc: 0.7932 - val_loss: 2.9128 - val_acc: 0.7980
#
# Epoch 00006: val_acc did not improve from 0.80400
# Epoch 7/200
# 498/498 [==============================] - 1s 2ms/step - loss: 2.7523 - acc: 0.8173 - val_loss: 3.3111 - val_acc: 0.7860
#
# Epoch 00007: val_acc did not improve from 0.80400
# Epoch 8/200
# 498/498 [==============================] - 1s 2ms/step - loss: 2.4781 - acc: 0.8394 - val_loss: 3.3544 - val_acc: 0.7840
#
# Epoch 00008: val_acc did not improve from 0.80400
# Epoch 9/200
# 498/498 [==============================] - 1s 2ms/step - loss: 2.4311 - acc: 0.8414 - val_loss: 3.2267 - val_acc: 0.7780
#
# Epoch 00009: val_acc did not improve from 0.80400
# Epoch 10/200
# 498/498 [==============================] - 1s 2ms/step - loss: 2.9567 - acc: 0.8133 - val_loss: 2.7374 - val_acc: 0.8160
#
# Epoch 00010: val_acc improved from 0.80400 to 0.81600, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 11/200
# 498/498 [==============================] - 1s 2ms/step - loss: 2.5974 - acc: 0.8293 - val_loss: 2.8026 - val_acc: 0.8120
#
# Epoch 00011: val_acc did not improve from 0.81600
# Epoch 12/200
# 498/498 [==============================] - 1s 2ms/step - loss: 2.0502 - acc: 0.8675 - val_loss: 3.6189 - val_acc: 0.7700
#
# Epoch 00012: val_acc did not improve from 0.81600
# Epoch 13/200
# 498/498 [==============================] - 1s 2ms/step - loss: 2.2263 - acc: 0.8474 - val_loss: 2.8303 - val_acc: 0.8160
#
# Epoch 00013: val_acc did not improve from 0.81600
# Epoch 14/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.4686 - acc: 0.9036 - val_loss: 2.7578 - val_acc: 0.8220
#
# Epoch 00014: val_acc improved from 0.81600 to 0.82200, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 15/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.7967 - acc: 0.8835 - val_loss: 3.8751 - val_acc: 0.7560
#
# Epoch 00015: val_acc did not improve from 0.82200
# Epoch 16/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.4999 - acc: 0.8996 - val_loss: 2.7430 - val_acc: 0.8220
#
# Epoch 00016: val_acc did not improve from 0.82200
# Epoch 17/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.4475 - acc: 0.9056 - val_loss: 2.5921 - val_acc: 0.8320
#
# Epoch 00017: val_acc improved from 0.82200 to 0.83200, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 18/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.7447 - acc: 0.8855 - val_loss: 3.0482 - val_acc: 0.8020
#
# Epoch 00018: val_acc did not improve from 0.83200
# Epoch 19/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.5491 - acc: 0.8996 - val_loss: 2.5540 - val_acc: 0.8320
#
# Epoch 00019: val_acc did not improve from 0.83200
# Epoch 20/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.3182 - acc: 0.9137 - val_loss: 2.4129 - val_acc: 0.8440
#
# Epoch 00020: val_acc improved from 0.83200 to 0.84400, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 21/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.4184 - acc: 0.9116 - val_loss: 2.5345 - val_acc: 0.8340
#
# Epoch 00021: val_acc did not improve from 0.84400
# Epoch 22/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.3690 - acc: 0.9116 - val_loss: 2.6651 - val_acc: 0.8240
#
# Epoch 00022: val_acc did not improve from 0.84400
# Epoch 23/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.3243 - acc: 0.9116 - val_loss: 2.6888 - val_acc: 0.8320
#
# Epoch 00023: val_acc did not improve from 0.84400
# Epoch 24/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.4149 - acc: 0.9076 - val_loss: 2.5361 - val_acc: 0.8360
#
# Epoch 00024: val_acc did not improve from 0.84400
# Epoch 25/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.2138 - acc: 0.9197 - val_loss: 2.5395 - val_acc: 0.8360
#
# Epoch 00025: val_acc did not improve from 0.84400
# Epoch 26/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.1250 - acc: 0.9297 - val_loss: 2.5395 - val_acc: 0.8360
#
# Epoch 00026: val_acc did not improve from 0.84400
# Epoch 27/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.0623 - acc: 0.9317 - val_loss: 2.6250 - val_acc: 0.8300
#
# Epoch 00027: val_acc did not improve from 0.84400
# Epoch 28/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.2478 - acc: 0.9177 - val_loss: 2.5186 - val_acc: 0.8380
#
# Epoch 00028: val_acc did not improve from 0.84400
# Epoch 29/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.1123 - acc: 0.9277 - val_loss: 2.4336 - val_acc: 0.8260
#
# Epoch 00029: val_acc did not improve from 0.84400
# Epoch 30/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.1016 - acc: 0.9237 - val_loss: 2.5360 - val_acc: 0.8400
#
# Epoch 00030: val_acc did not improve from 0.84400
# Epoch 31/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.2768 - acc: 0.9177 - val_loss: 2.5051 - val_acc: 0.8280
#
# Epoch 00031: val_acc did not improve from 0.84400
# Epoch 32/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.8364 - acc: 0.9478 - val_loss: 2.5106 - val_acc: 0.8320
#
# Epoch 00032: val_acc did not improve from 0.84400
# Epoch 33/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7797 - acc: 0.9498 - val_loss: 2.3488 - val_acc: 0.8420
#
# Epoch 00033: val_acc did not improve from 0.84400
# Epoch 34/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.1223 - acc: 0.9297 - val_loss: 2.5472 - val_acc: 0.8360
#
# Epoch 00034: val_acc did not improve from 0.84400
# Epoch 35/200
# 498/498 [==============================] - 1s 2ms/step - loss: 1.1278 - acc: 0.9257 - val_loss: 2.4139 - val_acc: 0.8400
#
# Epoch 00035: val_acc did not improve from 0.84400
# Epoch 36/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.8834 - acc: 0.9357 - val_loss: 2.5174 - val_acc: 0.8400
#
# Epoch 00036: val_acc did not improve from 0.84400
# Epoch 37/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7409 - acc: 0.9498 - val_loss: 2.5203 - val_acc: 0.8380
#
# Epoch 00037: val_acc did not improve from 0.84400
# Epoch 38/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7508 - acc: 0.9498 - val_loss: 2.4953 - val_acc: 0.8340
#
# Epoch 00038: val_acc did not improve from 0.84400
# Epoch 39/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.9688 - acc: 0.9378 - val_loss: 2.0761 - val_acc: 0.8580
#
# Epoch 00039: val_acc improved from 0.84400 to 0.85800, saving model to auxiliary/bottleneck_fc_model.h5
# Epoch 40/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7907 - acc: 0.9478 - val_loss: 2.3181 - val_acc: 0.8400
#
# Epoch 00040: val_acc did not improve from 0.85800
# Epoch 41/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7868 - acc: 0.9478 - val_loss: 2.7276 - val_acc: 0.8260
#
# Epoch 00041: val_acc did not improve from 0.85800
# Epoch 42/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5989 - acc: 0.9598 - val_loss: 2.3269 - val_acc: 0.8460
#
# Epoch 00042: val_acc did not improve from 0.85800
# Epoch 43/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5467 - acc: 0.9659 - val_loss: 2.2839 - val_acc: 0.8520
#
# Epoch 00043: val_acc did not improve from 0.85800
# Epoch 44/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7333 - acc: 0.9538 - val_loss: 2.2911 - val_acc: 0.8460
#
# Epoch 00044: val_acc did not improve from 0.85800
# Epoch 45/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.8122 - acc: 0.9458 - val_loss: 2.9850 - val_acc: 0.8060
#
# Epoch 00045: val_acc did not improve from 0.85800
# Epoch 46/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7100 - acc: 0.9558 - val_loss: 2.4173 - val_acc: 0.8420
#
# Epoch 00046: val_acc did not improve from 0.85800
# Epoch 47/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.8528 - acc: 0.9458 - val_loss: 2.5408 - val_acc: 0.8360
#
# Epoch 00047: val_acc did not improve from 0.85800
# Epoch 48/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.6743 - acc: 0.9578 - val_loss: 2.2760 - val_acc: 0.8520
#
# Epoch 00048: val_acc did not improve from 0.85800
# Epoch 49/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5146 - acc: 0.9659 - val_loss: 2.3663 - val_acc: 0.8480
#
# Epoch 00049: val_acc did not improve from 0.85800
# Epoch 50/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.6039 - acc: 0.9578 - val_loss: 2.3638 - val_acc: 0.8440
#
# Epoch 00050: val_acc did not improve from 0.85800
# Epoch 51/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3694 - acc: 0.9759 - val_loss: 2.6545 - val_acc: 0.8280
#
# Epoch 00051: val_acc did not improve from 0.85800
# Epoch 52/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.6009 - acc: 0.9598 - val_loss: 2.5606 - val_acc: 0.8340
#
# Epoch 00052: val_acc did not improve from 0.85800
# Epoch 53/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4656 - acc: 0.9679 - val_loss: 2.4695 - val_acc: 0.8380
#
# Epoch 00053: val_acc did not improve from 0.85800
# Epoch 54/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5322 - acc: 0.9639 - val_loss: 2.5515 - val_acc: 0.8360
#
# Epoch 00054: val_acc did not improve from 0.85800
# Epoch 55/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5362 - acc: 0.9659 - val_loss: 2.2839 - val_acc: 0.8520
#
# Epoch 00055: val_acc did not improve from 0.85800
# Epoch 56/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4960 - acc: 0.9679 - val_loss: 2.6416 - val_acc: 0.8260
#
# Epoch 00056: val_acc did not improve from 0.85800
# Epoch 57/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.6020 - acc: 0.9618 - val_loss: 2.3581 - val_acc: 0.8460
#
# Epoch 00057: val_acc did not improve from 0.85800
# Epoch 58/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.7448 - acc: 0.9498 - val_loss: 2.3710 - val_acc: 0.8480
#
# Epoch 00058: val_acc did not improve from 0.85800
# Epoch 59/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3914 - acc: 0.9739 - val_loss: 2.2692 - val_acc: 0.8440
#
# Epoch 00059: val_acc did not improve from 0.85800
# Epoch 60/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4503 - acc: 0.9719 - val_loss: 2.2692 - val_acc: 0.8440
#
# Epoch 00060: val_acc did not improve from 0.85800
# Epoch 61/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3863 - acc: 0.9759 - val_loss: 2.2692 - val_acc: 0.8440
#
# Epoch 00061: val_acc did not improve from 0.85800
# Epoch 62/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5062 - acc: 0.9659 - val_loss: 2.3353 - val_acc: 0.8500
#
# Epoch 00062: val_acc did not improve from 0.85800
# Epoch 63/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5253 - acc: 0.9659 - val_loss: 2.4398 - val_acc: 0.8400
#
# Epoch 00063: val_acc did not improve from 0.85800
# Epoch 64/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4132 - acc: 0.9739 - val_loss: 2.4059 - val_acc: 0.8460
#
# Epoch 00064: val_acc did not improve from 0.85800
# Epoch 65/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4768 - acc: 0.9679 - val_loss: 2.5785 - val_acc: 0.8360
#
# Epoch 00065: val_acc did not improve from 0.85800
# Epoch 66/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5810 - acc: 0.9618 - val_loss: 2.7223 - val_acc: 0.8280
#
# Epoch 00066: val_acc did not improve from 0.85800
# Epoch 67/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4904 - acc: 0.9679 - val_loss: 2.5824 - val_acc: 0.8380
#
# Epoch 00067: val_acc did not improve from 0.85800
# Epoch 68/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4837 - acc: 0.9699 - val_loss: 2.5858 - val_acc: 0.8360
#
# Epoch 00068: val_acc did not improve from 0.85800
# Epoch 69/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4446 - acc: 0.9719 - val_loss: 2.6683 - val_acc: 0.8280
#
# Epoch 00069: val_acc did not improve from 0.85800
# Epoch 70/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5277 - acc: 0.9659 - val_loss: 3.0934 - val_acc: 0.7980
#
# Epoch 00070: val_acc did not improve from 0.85800
# Epoch 71/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.6034 - acc: 0.9618 - val_loss: 2.7507 - val_acc: 0.8260
#
# Epoch 00071: val_acc did not improve from 0.85800
# Epoch 72/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2577 - acc: 0.9839 - val_loss: 2.6087 - val_acc: 0.8260
#
# Epoch 00072: val_acc did not improve from 0.85800
# Epoch 73/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3450 - acc: 0.9759 - val_loss: 2.6660 - val_acc: 0.8280
#
# Epoch 00073: val_acc did not improve from 0.85800
# Epoch 74/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5781 - acc: 0.9618 - val_loss: 2.3781 - val_acc: 0.8440
#
# Epoch 00074: val_acc did not improve from 0.85800
# Epoch 75/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3109 - acc: 0.9799 - val_loss: 2.7924 - val_acc: 0.8200
#
# Epoch 00075: val_acc did not improve from 0.85800
# Epoch 76/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4489 - acc: 0.9719 - val_loss: 2.5223 - val_acc: 0.8400
#
# Epoch 00076: val_acc did not improve from 0.85800
# Epoch 77/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2787 - acc: 0.9819 - val_loss: 2.4622 - val_acc: 0.8440
#
# Epoch 00077: val_acc did not improve from 0.85800
# Epoch 78/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4503 - acc: 0.9719 - val_loss: 2.4651 - val_acc: 0.8400
#
# Epoch 00078: val_acc did not improve from 0.85800
# Epoch 79/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3212 - acc: 0.9799 - val_loss: 2.4651 - val_acc: 0.8400
#
# Epoch 00079: val_acc did not improve from 0.85800
# Epoch 80/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3387 - acc: 0.9779 - val_loss: 2.5415 - val_acc: 0.8340
#
# Epoch 00080: val_acc did not improve from 0.85800
# Epoch 81/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3959 - acc: 0.9739 - val_loss: 2.5413 - val_acc: 0.8320
#
# Epoch 00081: val_acc did not improve from 0.85800
# Epoch 82/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3219 - acc: 0.9799 - val_loss: 2.4974 - val_acc: 0.8380
#
# Epoch 00082: val_acc did not improve from 0.85800
# Epoch 83/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3691 - acc: 0.9739 - val_loss: 2.5315 - val_acc: 0.8360
#
# Epoch 00083: val_acc did not improve from 0.85800
# Epoch 84/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3546 - acc: 0.9759 - val_loss: 3.0484 - val_acc: 0.8020
#
# Epoch 00084: val_acc did not improve from 0.85800
# Epoch 85/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.5981 - acc: 0.9618 - val_loss: 2.5980 - val_acc: 0.8300
#
# Epoch 00085: val_acc did not improve from 0.85800
# Epoch 86/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3000 - acc: 0.9779 - val_loss: 2.6855 - val_acc: 0.8300
#
# Epoch 00086: val_acc did not improve from 0.85800
# Epoch 87/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3543 - acc: 0.9779 - val_loss: 2.6197 - val_acc: 0.8320
#
# Epoch 00087: val_acc did not improve from 0.85800
# Epoch 88/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2415 - acc: 0.9839 - val_loss: 2.4669 - val_acc: 0.8360
#
# Epoch 00088: val_acc did not improve from 0.85800
# Epoch 89/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2884 - acc: 0.9819 - val_loss: 2.5419 - val_acc: 0.8400
#
# Epoch 00089: val_acc did not improve from 0.85800
# Epoch 90/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2895 - acc: 0.9819 - val_loss: 2.4891 - val_acc: 0.8400
#
# Epoch 00090: val_acc did not improve from 0.85800
# Epoch 91/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3215 - acc: 0.9799 - val_loss: 2.7023 - val_acc: 0.8260
#
# Epoch 00091: val_acc did not improve from 0.85800
# Epoch 92/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3133 - acc: 0.9799 - val_loss: 2.5850 - val_acc: 0.8320
#
# Epoch 00092: val_acc did not improve from 0.85800
# Epoch 93/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.5157 - val_acc: 0.8340
#
# Epoch 00093: val_acc did not improve from 0.85800
# Epoch 94/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5157 - val_acc: 0.8340
#
# Epoch 00094: val_acc did not improve from 0.85800
# Epoch 95/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5157 - val_acc: 0.8340
#
# Epoch 00095: val_acc did not improve from 0.85800
# Epoch 96/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.6093 - val_acc: 0.8340
#
# Epoch 00096: val_acc did not improve from 0.85800
# Epoch 97/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3219 - acc: 0.9799 - val_loss: 2.6093 - val_acc: 0.8340
#
# Epoch 00097: val_acc did not improve from 0.85800
# Epoch 98/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5002 - val_acc: 0.8420
#
# Epoch 00098: val_acc did not improve from 0.85800
# Epoch 99/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4605 - val_acc: 0.8400
#
# Epoch 00099: val_acc did not improve from 0.85800
# Epoch 100/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4605 - val_acc: 0.8400
#
# Epoch 00100: val_acc did not improve from 0.85800
# Epoch 101/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4605 - val_acc: 0.8400
#
# Epoch 00101: val_acc did not improve from 0.85800
# Epoch 102/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4605 - val_acc: 0.8400
#
# Epoch 00102: val_acc did not improve from 0.85800
# Epoch 103/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2565 - acc: 0.9839 - val_loss: 2.5201 - val_acc: 0.8320
#
# Epoch 00103: val_acc did not improve from 0.85800
# Epoch 104/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5201 - val_acc: 0.8320
#
# Epoch 00104: val_acc did not improve from 0.85800
# Epoch 105/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2339 - acc: 0.9839 - val_loss: 2.5098 - val_acc: 0.8380
#
# Epoch 00105: val_acc did not improve from 0.85800
# Epoch 106/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5098 - val_acc: 0.8380
#
# Epoch 00106: val_acc did not improve from 0.85800
# Epoch 107/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6231 - val_acc: 0.8280
#
# Epoch 00107: val_acc did not improve from 0.85800
# Epoch 108/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.6231 - val_acc: 0.8280
#
# Epoch 00108: val_acc did not improve from 0.85800
# Epoch 109/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.4949 - val_acc: 0.8420
#
# Epoch 00109: val_acc did not improve from 0.85800
# Epoch 110/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4949 - val_acc: 0.8420
#
# Epoch 00110: val_acc did not improve from 0.85800
# Epoch 111/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.4335 - acc: 0.9719 - val_loss: 2.6186 - val_acc: 0.8280
#
# Epoch 00111: val_acc did not improve from 0.85800
# Epoch 112/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6186 - val_acc: 0.8280
#
# Epoch 00112: val_acc did not improve from 0.85800
# Epoch 113/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2261 - acc: 0.9859 - val_loss: 2.5655 - val_acc: 0.8380
#
# Epoch 00113: val_acc did not improve from 0.85800
# Epoch 114/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.5655 - val_acc: 0.8380
#
# Epoch 00114: val_acc did not improve from 0.85800
# Epoch 115/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5655 - val_acc: 0.8380
#
# Epoch 00115: val_acc did not improve from 0.85800
# Epoch 116/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2588 - acc: 0.9819 - val_loss: 2.4649 - val_acc: 0.8440
#
# Epoch 00116: val_acc did not improve from 0.85800
# Epoch 117/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2572 - acc: 0.9839 - val_loss: 2.6632 - val_acc: 0.8260
#
# Epoch 00117: val_acc did not improve from 0.85800
# Epoch 118/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.6632 - val_acc: 0.8260
#
# Epoch 00118: val_acc did not improve from 0.85800
# Epoch 119/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3777 - acc: 0.9759 - val_loss: 2.6519 - val_acc: 0.8340
#
# Epoch 00119: val_acc did not improve from 0.85800
# Epoch 120/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2269 - acc: 0.9839 - val_loss: 2.5059 - val_acc: 0.8400
#
# Epoch 00120: val_acc did not improve from 0.85800
# Epoch 121/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2895 - acc: 0.9819 - val_loss: 2.5262 - val_acc: 0.8380
#
# Epoch 00121: val_acc did not improve from 0.85800
# Epoch 122/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2572 - acc: 0.9839 - val_loss: 2.5262 - val_acc: 0.8380
#
# Epoch 00122: val_acc did not improve from 0.85800
# Epoch 123/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2895 - acc: 0.9819 - val_loss: 2.4600 - val_acc: 0.8340
#
# Epoch 00123: val_acc did not improve from 0.85800
# Epoch 124/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.4600 - val_acc: 0.8340
#
# Epoch 00124: val_acc did not improve from 0.85800
# Epoch 125/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4600 - val_acc: 0.8340
#
# Epoch 00125: val_acc did not improve from 0.85800
# Epoch 126/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4600 - val_acc: 0.8340
#
# Epoch 00126: val_acc did not improve from 0.85800
# Epoch 127/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4600 - val_acc: 0.8340
#
# Epoch 00127: val_acc did not improve from 0.85800
# Epoch 128/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4103 - val_acc: 0.8460
#
# Epoch 00128: val_acc did not improve from 0.85800
# Epoch 129/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2338 - acc: 0.9839 - val_loss: 2.4856 - val_acc: 0.8400
#
# Epoch 00129: val_acc did not improve from 0.85800
# Epoch 130/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.4856 - val_acc: 0.8400
#
# Epoch 00130: val_acc did not improve from 0.85800
# Epoch 131/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.3563 - val_acc: 0.8500
#
# Epoch 00131: val_acc did not improve from 0.85800
# Epoch 132/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2892 - acc: 0.9819 - val_loss: 2.3563 - val_acc: 0.8500
#
# Epoch 00132: val_acc did not improve from 0.85800
# Epoch 133/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.3563 - val_acc: 0.8500
#
# Epoch 00133: val_acc did not improve from 0.85800
# Epoch 134/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.3563 - val_acc: 0.8500
#
# Epoch 00134: val_acc did not improve from 0.85800
# Epoch 135/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3783 - acc: 0.9759 - val_loss: 2.3272 - val_acc: 0.8520
#
# Epoch 00135: val_acc did not improve from 0.85800
# Epoch 136/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2329 - acc: 0.9839 - val_loss: 2.5127 - val_acc: 0.8380
#
# Epoch 00136: val_acc did not improve from 0.85800
# Epoch 137/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5127 - val_acc: 0.8380
#
# Epoch 00137: val_acc did not improve from 0.85800
# Epoch 138/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.5127 - val_acc: 0.8380
#
# Epoch 00138: val_acc did not improve from 0.85800
# Epoch 139/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5127 - val_acc: 0.8380
#
# Epoch 00139: val_acc did not improve from 0.85800
# Epoch 140/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5127 - val_acc: 0.8380
#
# Epoch 00140: val_acc did not improve from 0.85800
# Epoch 141/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2643 - acc: 0.9819 - val_loss: 2.4721 - val_acc: 0.8420
#
# Epoch 00141: val_acc did not improve from 0.85800
# Epoch 142/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4721 - val_acc: 0.8420
#
# Epoch 00142: val_acc did not improve from 0.85800
# Epoch 143/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4721 - val_acc: 0.8420
#
# Epoch 00143: val_acc did not improve from 0.85800
# Epoch 144/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4721 - val_acc: 0.8420
#
# Epoch 00144: val_acc did not improve from 0.85800
# Epoch 145/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.5158 - val_acc: 0.8360
#
# Epoch 00145: val_acc did not improve from 0.85800
# Epoch 146/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2421 - acc: 0.9839 - val_loss: 2.5980 - val_acc: 0.8360
#
# Epoch 00146: val_acc did not improve from 0.85800
# Epoch 147/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5980 - val_acc: 0.8360
#
# Epoch 00147: val_acc did not improve from 0.85800
# Epoch 148/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5980 - val_acc: 0.8360
#
# Epoch 00148: val_acc did not improve from 0.85800
# Epoch 149/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5980 - val_acc: 0.8360
#
# Epoch 00149: val_acc did not improve from 0.85800
# Epoch 150/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5980 - val_acc: 0.8360
#
# Epoch 00150: val_acc did not improve from 0.85800
# Epoch 151/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4427 - val_acc: 0.8440
#
# Epoch 00151: val_acc did not improve from 0.85800
# Epoch 152/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2572 - acc: 0.9839 - val_loss: 2.4427 - val_acc: 0.8440
#
# Epoch 00152: val_acc did not improve from 0.85800
# Epoch 153/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4427 - val_acc: 0.8440
#
# Epoch 00153: val_acc did not improve from 0.85800
# Epoch 154/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00154: val_acc did not improve from 0.85800
# Epoch 155/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00155: val_acc did not improve from 0.85800
# Epoch 156/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00156: val_acc did not improve from 0.85800
# Epoch 157/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00157: val_acc did not improve from 0.85800
# Epoch 158/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00158: val_acc did not improve from 0.85800
# Epoch 159/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00159: val_acc did not improve from 0.85800
# Epoch 160/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00160: val_acc did not improve from 0.85800
# Epoch 161/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00161: val_acc did not improve from 0.85800
# Epoch 162/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.6803 - val_acc: 0.8280
#
# Epoch 00162: val_acc did not improve from 0.85800
# Epoch 163/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2572 - acc: 0.9839 - val_loss: 2.5276 - val_acc: 0.8400
#
# Epoch 00163: val_acc did not improve from 0.85800
# Epoch 164/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2572 - acc: 0.9839 - val_loss: 2.5276 - val_acc: 0.8400
#
# Epoch 00164: val_acc did not improve from 0.85800
# Epoch 165/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2324 - acc: 0.9839 - val_loss: 2.5490 - val_acc: 0.8360
#
# Epoch 00165: val_acc did not improve from 0.85800
# Epoch 166/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5490 - val_acc: 0.8360
#
# Epoch 00166: val_acc did not improve from 0.85800
# Epoch 167/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5490 - val_acc: 0.8360
#
# Epoch 00167: val_acc did not improve from 0.85800
# Epoch 168/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2362 - acc: 0.9839 - val_loss: 2.4746 - val_acc: 0.8360
#
# Epoch 00168: val_acc did not improve from 0.85800
# Epoch 169/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.4746 - val_acc: 0.8360
#
# Epoch 00169: val_acc did not improve from 0.85800
# Epoch 170/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2568 - acc: 0.9839 - val_loss: 2.4746 - val_acc: 0.8360
#
# Epoch 00170: val_acc did not improve from 0.85800
# Epoch 171/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.4746 - val_acc: 0.8360
#
# Epoch 00171: val_acc did not improve from 0.85800
# Epoch 172/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.3711 - val_acc: 0.8420
#
# Epoch 00172: val_acc did not improve from 0.85800
# Epoch 173/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2248 - acc: 0.9859 - val_loss: 2.5860 - val_acc: 0.8340
#
# Epoch 00173: val_acc did not improve from 0.85800
# Epoch 174/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5701 - val_acc: 0.8340
#
# Epoch 00174: val_acc did not improve from 0.85800
# Epoch 175/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5701 - val_acc: 0.8340
#
# Epoch 00175: val_acc did not improve from 0.85800
# Epoch 176/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5701 - val_acc: 0.8340
#
# Epoch 00176: val_acc did not improve from 0.85800
# Epoch 177/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2216 - acc: 0.9859 - val_loss: 2.5132 - val_acc: 0.8400
#
# Epoch 00177: val_acc did not improve from 0.85800
# Epoch 178/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2661 - acc: 0.9819 - val_loss: 2.5522 - val_acc: 0.8340
#
# Epoch 00178: val_acc did not improve from 0.85800
# Epoch 179/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2252 - acc: 0.9859 - val_loss: 2.6430 - val_acc: 0.8280
#
# Epoch 00179: val_acc did not improve from 0.85800
# Epoch 180/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2251 - acc: 0.9859 - val_loss: 2.6430 - val_acc: 0.8280
#
# Epoch 00180: val_acc did not improve from 0.85800
# Epoch 181/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00181: val_acc did not improve from 0.85800
# Epoch 182/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00182: val_acc did not improve from 0.85800
# Epoch 183/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00183: val_acc did not improve from 0.85800
# Epoch 184/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2251 - acc: 0.9859 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00184: val_acc did not improve from 0.85800
# Epoch 185/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00185: val_acc did not improve from 0.85800
# Epoch 186/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00186: val_acc did not improve from 0.85800
# Epoch 187/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2251 - acc: 0.9859 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00187: val_acc did not improve from 0.85800
# Epoch 188/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00188: val_acc did not improve from 0.85800
# Epoch 189/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00189: val_acc did not improve from 0.85800
# Epoch 190/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2251 - acc: 0.9859 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00190: val_acc did not improve from 0.85800
# Epoch 191/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.5360 - val_acc: 0.8360
#
# Epoch 00191: val_acc did not improve from 0.85800
# Epoch 192/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2285 - acc: 0.9839 - val_loss: 2.6101 - val_acc: 0.8340
#
# Epoch 00192: val_acc did not improve from 0.85800
# Epoch 193/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2184 - acc: 0.9859 - val_loss: 2.4842 - val_acc: 0.8420
#
# Epoch 00193: val_acc did not improve from 0.85800
# Epoch 194/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.4842 - val_acc: 0.8420
#
# Epoch 00194: val_acc did not improve from 0.85800
# Epoch 195/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.4842 - val_acc: 0.8420
#
# Epoch 00195: val_acc did not improve from 0.85800
# Epoch 196/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.4842 - val_acc: 0.8420
#
# Epoch 00196: val_acc did not improve from 0.85800
# Epoch 197/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2301 - acc: 0.9839 - val_loss: 2.5172 - val_acc: 0.8380
#
# Epoch 00197: val_acc did not improve from 0.85800
# Epoch 198/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.2258 - acc: 0.9839 - val_loss: 2.6411 - val_acc: 0.8320
#
# Epoch 00198: val_acc did not improve from 0.85800
# Epoch 199/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.6411 - val_acc: 0.8320
#
# Epoch 00199: val_acc did not improve from 0.85800
# Epoch 200/200
# 498/498 [==============================] - 1s 2ms/step - loss: 0.1928 - acc: 0.9880 - val_loss: 2.6411 - val_acc: 0.8320
#
# Epoch 00200: val_acc did not improve from 0.85800

# %% [markdown]
# ## Fine-tuning the top layers of a a pre-trained network

# %% [markdown]
# After instantiating the VGG base and loading its weights, we add our previously trained fully-connected classifier on top. We start with a fully-trained classifier, including the top classifier, in order to successfully do fine-tuning.

# %%
base_model = VGG16(
    include_top=False, weights="imagenet", input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)
)

top_model = generate_top_model(input_shape=(base_model.output_shape[1:]))
top_model.load_weights(TOP_MODEL_WEIGHTS_PATH)

# add the model on top of the convolutional base
model = Model(inputs=base_model.input, outputs=top_model(base_model.output))

# %% [markdown]
# We'll be freezing all convolutional layers up to the last convolutional block and only fine tune the last one which has more specialized features. Let's take a look at our model's layers to freeze the right amount.

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f467c6fdc50>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c6f4890>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c11c610>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f467c6f4f10>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c6edfd0>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c414b50>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f467c44d290>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c44d690>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c4034d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c394bd0>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f467c3c1350>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c3c15d0>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c377410>,
#  <keras.layers.convolutional.Conv2D at 0x7f467c389d50>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f4677be9f10>,
#  <keras.layers.convolutional.Conv2D at 0x7f4677be9390>,
#  <keras.layers.convolutional.Conv2D at 0x7f4677bffd90>,
#  <keras.layers.convolutional.Conv2D at 0x7f4677bb1c10>,
#  <keras.layers.pooling.MaxPooling2D at 0x7f4677b68c90>,
#  <keras.engine.sequential.Sequential at 0x7f467c6fdf90>]

# %%
# freeze the first 15 layers (up to the last conv block)
for layer in model.layers[:15]:
    layer.trainable = False

model.compile(
    loss="binary_crossentropy",
    optimizer=RMSprop(lr=3e-6),
    metrics=["accuracy"],
)

# %% [markdown]
# Let's check that the last convolutional block and our top fully-connected model are trainable.

# %%
for layer in model.layers:
    print(f"{layer.name}\t{layer.trainable}")
# Out:
# input_2	False
# block1_conv1	False
# block1_conv2	False
# block1_pool	False
# block2_conv1	False
# block2_conv2	False
# block2_pool	False
# block3_conv1	False
# block3_conv2	False
# block3_conv3	False
# block3_pool	False
# block4_conv1	False
# block4_conv2	False
# block4_conv3	False
# block4_pool	False
# block5_conv1	True
# block5_conv2	True
# block5_conv3	True
# block5_pool	True
# sequential_2	True

# %%
train_generator = get_batches(TRAIN_DATA_DIR)
validation_generator = get_batches(VALIDATION_DATA_DIR)

checkpoint = ModelCheckpoint(
    TUNED_VGG_WEIGHTS_PATH,
    monitor="val_acc",
    verbose=1,
    save_best_only=True,
    mode="max",
)

model.fit_generator(
    train_generator,
    steps_per_epoch=ceil(TRAIN_CLASS_SIZE * 2 / BATCH_SIZE),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=ceil(VALIDATION_CLASS_SIZE * 2 / BATCH_SIZE),
    callbacks=[checkpoint],
)
# Out:
# Found 498 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# Epoch 1/50
# 32/32 [==============================] - 86s 3s/step - loss: 0.6514 - acc: 0.9589 - val_loss: 2.2564 - val_acc: 0.8560
#
# Epoch 00001: val_acc improved from -inf to 0.85600, saving model to auxiliary/tuned_vgg_model.h5
# Epoch 2/50
# 32/32 [==============================] - 79s 2s/step - loss: 0.8262 - acc: 0.9472 - val_loss: 2.3329 - val_acc: 0.8480
#
# Epoch 00002: val_acc did not improve from 0.85600
# Epoch 3/50
# 32/32 [==============================] - 77s 2s/step - loss: 0.6451 - acc: 0.9570 - val_loss: 2.2611 - val_acc: 0.8580
#
# Epoch 00003: val_acc improved from 0.85600 to 0.85800, saving model to auxiliary/tuned_vgg_model.h5
# Epoch 4/50
# 32/32 [==============================] - 74s 2s/step - loss: 0.5632 - acc: 0.9648 - val_loss: 2.1194 - val_acc: 0.8580
#
# Epoch 00004: val_acc did not improve from 0.85800
# Epoch 5/50
# 32/32 [==============================] - 75s 2s/step - loss: 0.5564 - acc: 0.9629 - val_loss: 2.3379 - val_acc: 0.8440
#
# Epoch 00005: val_acc did not improve from 0.85800
# Epoch 6/50
# 32/32 [==============================] - 74s 2s/step - loss: 0.5154 - acc: 0.9648 - val_loss: 2.2951 - val_acc: 0.8500
#
# Epoch 00006: val_acc did not improve from 0.85800
# Epoch 7/50
# 32/32 [==============================] - 75s 2s/step - loss: 0.8052 - acc: 0.9496 - val_loss: 2.0844 - val_acc: 0.8640
#
# Epoch 00007: val_acc improved from 0.85800 to 0.86400, saving model to auxiliary/tuned_vgg_model.h5
# Epoch 8/50
# 32/32 [==============================] - 73s 2s/step - loss: 0.5635 - acc: 0.9648 - val_loss: 2.3495 - val_acc: 0.8500
#
# Epoch 00008: val_acc did not improve from 0.86400
# Epoch 9/50
# 32/32 [==============================] - 75s 2s/step - loss: 0.4759 - acc: 0.9668 - val_loss: 2.4470 - val_acc: 0.8420
#
# Epoch 00009: val_acc did not improve from 0.86400
# Epoch 10/50
# 32/32 [==============================] - 83s 3s/step - loss: 0.8549 - acc: 0.9453 - val_loss: 2.3924 - val_acc: 0.8420
#
# Epoch 00010: val_acc did not improve from 0.86400
# Epoch 11/50
# 32/32 [==============================] - 80s 3s/step - loss: 0.4305 - acc: 0.9726 - val_loss: 2.2686 - val_acc: 0.8500
#
# Epoch 00011: val_acc did not improve from 0.86400
# Epoch 12/50
# 32/32 [==============================] - 87s 3s/step - loss: 0.6191 - acc: 0.9589 - val_loss: 2.3588 - val_acc: 0.8480
#
# Epoch 00012: val_acc did not improve from 0.86400
# Epoch 13/50
# 32/32 [==============================] - 86s 3s/step - loss: 0.5143 - acc: 0.9668 - val_loss: 2.3916 - val_acc: 0.8460
#
# Epoch 00013: val_acc did not improve from 0.86400
# Epoch 14/50
# 32/32 [==============================] - 77s 2s/step - loss: 0.7166 - acc: 0.9550 - val_loss: 2.1743 - val_acc: 0.8620
#
# Epoch 00014: val_acc did not improve from 0.86400
# Epoch 15/50
# 32/32 [==============================] - 75s 2s/step - loss: 0.3874 - acc: 0.9746 - val_loss: 2.3647 - val_acc: 0.8480
#
# Epoch 00015: val_acc did not improve from 0.86400
# Epoch 16/50
# 32/32 [==============================] - 90s 3s/step - loss: 0.4695 - acc: 0.9707 - val_loss: 2.3598 - val_acc: 0.8460
#
# Epoch 00016: val_acc did not improve from 0.86400
# Epoch 17/50
# 32/32 [==============================] - 108s 3s/step - loss: 0.8140 - acc: 0.9476 - val_loss: 2.2578 - val_acc: 0.8520
#
# Epoch 00017: val_acc did not improve from 0.86400
# Epoch 18/50
# 32/32 [==============================] - 97s 3s/step - loss: 0.4251 - acc: 0.9687 - val_loss: 2.3316 - val_acc: 0.8500
#
# Epoch 00018: val_acc did not improve from 0.86400
# Epoch 19/50
# 32/32 [==============================] - 85s 3s/step - loss: 0.5573 - acc: 0.9609 - val_loss: 2.2145 - val_acc: 0.8560
#
# Epoch 00019: val_acc did not improve from 0.86400
# Epoch 20/50
# 32/32 [==============================] - 85s 3s/step - loss: 0.4848 - acc: 0.9687 - val_loss: 2.1347 - val_acc: 0.8560
#
# Epoch 00020: val_acc did not improve from 0.86400
# Epoch 21/50
# 32/32 [==============================] - 83s 3s/step - loss: 0.3750 - acc: 0.9765 - val_loss: 2.1276 - val_acc: 0.8580
#
# Epoch 00021: val_acc did not improve from 0.86400
# Epoch 22/50
# 32/32 [==============================] - 85s 3s/step - loss: 0.4851 - acc: 0.9668 - val_loss: 2.2699 - val_acc: 0.8500
#
# Epoch 00022: val_acc did not improve from 0.86400
# Epoch 23/50
# 32/32 [==============================] - 79s 2s/step - loss: 0.3823 - acc: 0.9746 - val_loss: 2.1859 - val_acc: 0.8540
#
# Epoch 00023: val_acc did not improve from 0.86400
# Epoch 24/50
# 32/32 [==============================] - 79s 2s/step - loss: 0.4888 - acc: 0.9672 - val_loss: 2.1973 - val_acc: 0.8560
#
# Epoch 00024: val_acc did not improve from 0.86400
# Epoch 25/50
# 32/32 [==============================] - 89s 3s/step - loss: 0.4692 - acc: 0.9707 - val_loss: 2.2046 - val_acc: 0.8560
#
# Epoch 00025: val_acc did not improve from 0.86400
# Epoch 26/50
# 32/32 [==============================] - 78s 2s/step - loss: 0.4427 - acc: 0.9687 - val_loss: 2.3286 - val_acc: 0.8480
#
# Epoch 00026: val_acc did not improve from 0.86400
# Epoch 27/50
# 32/32 [==============================] - 77s 2s/step - loss: 0.4326 - acc: 0.9726 - val_loss: 2.1601 - val_acc: 0.8620
#
# Epoch 00027: val_acc did not improve from 0.86400
# Epoch 28/50
# 32/32 [==============================] - 81s 3s/step - loss: 0.4285 - acc: 0.9707 - val_loss: 2.3758 - val_acc: 0.8500
#
# Epoch 00028: val_acc did not improve from 0.86400
# Epoch 29/50
# 32/32 [==============================] - 78s 2s/step - loss: 0.3435 - acc: 0.9785 - val_loss: 2.4258 - val_acc: 0.8400
#
# Epoch 00029: val_acc did not improve from 0.86400
# Epoch 30/50
# 32/32 [==============================] - 80s 3s/step - loss: 0.5408 - acc: 0.9648 - val_loss: 2.3804 - val_acc: 0.8500
#
# Epoch 00030: val_acc did not improve from 0.86400
# Epoch 31/50
# 32/32 [==============================] - 82s 3s/step - loss: 0.4816 - acc: 0.9687 - val_loss: 2.3041 - val_acc: 0.8500
#
# Epoch 00031: val_acc did not improve from 0.86400
# Epoch 32/50
# 32/32 [==============================] - 80s 2s/step - loss: 0.4961 - acc: 0.9648 - val_loss: 2.1784 - val_acc: 0.8580
#
# Epoch 00032: val_acc did not improve from 0.86400
# Epoch 33/50
# 32/32 [==============================] - 81s 3s/step - loss: 0.3584 - acc: 0.9765 - val_loss: 2.1551 - val_acc: 0.8580
#
# Epoch 00033: val_acc did not improve from 0.86400
# Epoch 34/50
# 32/32 [==============================] - 77s 2s/step - loss: 0.4062 - acc: 0.9746 - val_loss: 2.1551 - val_acc: 0.8580
#
# Epoch 00034: val_acc did not improve from 0.86400
# Epoch 35/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.4688 - acc: 0.9707 - val_loss: 2.1678 - val_acc: 0.8560
#
# Epoch 00035: val_acc did not improve from 0.86400
# Epoch 36/50
# 32/32 [==============================] - 113s 4s/step - loss: 0.4270 - acc: 0.9726 - val_loss: 2.2223 - val_acc: 0.8560
#
# Epoch 00036: val_acc did not improve from 0.86400
# Epoch 37/50
# 32/32 [==============================] - 114s 4s/step - loss: 0.3521 - acc: 0.9765 - val_loss: 2.1083 - val_acc: 0.8620
#
# Epoch 00037: val_acc did not improve from 0.86400
# Epoch 38/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.4310 - acc: 0.9726 - val_loss: 2.3667 - val_acc: 0.8500
#
# Epoch 00038: val_acc did not improve from 0.86400
# Epoch 39/50
# 32/32 [==============================] - 76s 2s/step - loss: 0.3747 - acc: 0.9765 - val_loss: 2.2070 - val_acc: 0.8540
#
# Epoch 00039: val_acc did not improve from 0.86400
# Epoch 40/50
# 32/32 [==============================] - 76s 2s/step - loss: 0.3747 - acc: 0.9765 - val_loss: 2.2160 - val_acc: 0.8540
#
# Epoch 00040: val_acc did not improve from 0.86400
# Epoch 41/50
# 32/32 [==============================] - 101s 3s/step - loss: 0.3435 - acc: 0.9785 - val_loss: 2.2160 - val_acc: 0.8540
#
# Epoch 00041: val_acc did not improve from 0.86400
# Epoch 42/50
# 32/32 [==============================] - 105s 3s/step - loss: 0.3336 - acc: 0.9785 - val_loss: 2.2202 - val_acc: 0.8560
#
# Epoch 00042: val_acc did not improve from 0.86400
# Epoch 43/50
# 32/32 [==============================] - 117s 4s/step - loss: 0.3128 - acc: 0.9805 - val_loss: 2.2462 - val_acc: 0.8560
#
# Epoch 00043: val_acc did not improve from 0.86400
# Epoch 44/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.3065 - acc: 0.9805 - val_loss: 2.1525 - val_acc: 0.8560
#
# Epoch 00044: val_acc did not improve from 0.86400
# Epoch 45/50
# 32/32 [==============================] - 107s 3s/step - loss: 0.4686 - acc: 0.9687 - val_loss: 2.1858 - val_acc: 0.8560
#
# Epoch 00045: val_acc did not improve from 0.86400
# Epoch 46/50
# 32/32 [==============================] - 104s 3s/step - loss: 0.3760 - acc: 0.9765 - val_loss: 2.1738 - val_acc: 0.8560
#
# Epoch 00046: val_acc did not improve from 0.86400
# Epoch 47/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.2500 - acc: 0.9844 - val_loss: 2.1738 - val_acc: 0.8560
#
# Epoch 00047: val_acc did not improve from 0.86400
# Epoch 48/50
# 32/32 [==============================] - 102s 3s/step - loss: 0.3438 - acc: 0.9785 - val_loss: 2.1773 - val_acc: 0.8560
#
# Epoch 00048: val_acc did not improve from 0.86400
# Epoch 49/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.2812 - acc: 0.9824 - val_loss: 2.1725 - val_acc: 0.8560
#
# Epoch 00049: val_acc did not improve from 0.86400
# Epoch 50/50
# 32/32 [==============================] - 103s 3s/step - loss: 0.4065 - acc: 0.9746 - val_loss: 2.1582 - val_acc: 0.8640
#
# Epoch 00050: val_acc did not improve from 0.86400

# %% [markdown]
# With transfer learning we were able to increase accuracy to apprx 86% on the validation set comparing to 70% for our custom convnet model.
#
# Comparing fine tuning of the last convolutional block to training only fully connected model on top of VGG16 convolutional base, the increase in accuracy for the best checkpointed model is not that high - around 1%, but the values validation accuracy is varied around during training went from 82-83% to 85-86%.
